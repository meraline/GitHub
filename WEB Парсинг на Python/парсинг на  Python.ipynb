# %%
import requests
from random import choice
from fake_useragent import UserAgent
import time
from bs4 import BeautifulSoup
import lxml
import html5lib

# %%
url = 'http://httpbin.org/user-agent'

while line := open('user_agent.txt').read().split('\n'): # Заголовки headers= из файла
    user_agent = {'user-agent': choice(line)}
    response = requests.get(url=url, headers=user_agent)
    print(response.text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [170], in <cell line: 3>()
#       1 url = 'http://httpbin.org/user-agent'
# ----> 3 while line := open('user_agent.txt').read().split('\n'): # Заголовки headers= из файла
#       4     user_agent = {'user-agent': choice(line)}
#       5     response = requests.get(url=url, headers=user_agent)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'user_agent.txt'

# %%
# Библиотека fake_useragent

url = 'http://httpbin.org/user-agent'

for x in range(10):
    ua = UserAgent()
    fake_ua = {'user-agent': ua.random}
    response = requests.get(url=url, headers=fake_ua)
    print(response.text)

# %%
#Заголовки headers=

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.84 Safari/537.36',
}

response = requests.get(url='http://httpbin.org/user-agent', headers=headers)
print(response.text)

# %%
url = 'http://httpbin.org/ip'

with open('proxy.txt') as file:
    proxy_file = file.read().split('\n')
    for _ in range(1000):
        try:
            ip = choice(proxy_file).strip()
            proxy = {
                'http': f'http://{ip}',
                'https': f'http://{ip}'
            }
            response = requests.get(url=url, proxies=proxy)
            print(response.json(), 'Success connection')
        except Exception as _ex:
            continue

# %%
# Прокси proxies= Для всех, с авторизацией
proxy_all_auth = {
    'http':'socks5://login:password@103.177.45.3:80',
    'https':'socks5://login:password@103.177.45.3:80',
}

# %%
# Таймаут timeout=

url = 'http://httpbin.org/get'

proxies = {
    'http': 'http://200.12.55.90:80',
    'https': 'http://200.12.55.90:80'
}
start = time.perf_counter()
try:
    requests.get(url=url, proxies=proxies, timeout=1)
except Exception as _ex:
    print(_ex)
    print(time.perf_counter()- start)

# %%
# Передача параметров в URL params=
param= {'key1': 'value1', 'key2': 'value2'}  
r = requests.get('https://httpbin.org/get', params=param)
print(r.url)

# %%
url = 'https://parsinger.ru/video_downloads/videoplayback.mp4'

response = requests.get(url=url, stream=True)
with open('file.mp4', 'wb') as video:
    for piece in response.iter_content(chunk_size=100000):
        video.write(piece)

# %% [markdown]
# ## Статус кода

# %%
url = 'http://httpbin.org/'
response = requests.get(url)
print(response.status_code)

# %%
url = 'http://httpbin.org/'
response = requests.get(url)
if response.status_code == 200:
    print("status_code OK")
else:
    print("status_code NOT OK")

# %%
url = f'http://parsinger.ru/task/1/{x}.html'

х=1
response = requests.get(url)
if response.status_code != 200:
    х=+1
else:
    print(f'http://parsinger.ru/task/1/{x}.html')

# %%
s=0
i=1

while i<=500:
    s=s+i**2
    i=i+1
print("sum:",s)

# %%
# Статус кода 200 в сылке 333 
# это долгий способ, ниже код выполняется быстрее

x=1
while x <= 500:
    url = f'http://parsinger.ru/task/1/{x}.html'
    response = requests.get(url)
    if response.status_code != 200:
        x=x+1
        #print("status_code NO 200", "№-",x)
    else:
        soup = BeautifulSoup(response.text, 'lxml')
        div = soup.find('body')
        print(div.text)
        break

# %%
# ДЗ

for i in range(1, 501):
    url = f'http://parsinger.ru/task/1/{i}.html'
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'lxml')
        div = soup.find('body')
        print(div.text)
        break

# %% [markdown]
# ## Получение содержимого

# %%
response = requests.get(url='https://jsonplaceholder.typicode.com/todos/')
print(response.json())

# %%
response = requests.post(url='https://cloud.roistat.com/api/v1/project/analytics/data?project=75873&key=0aae516248a720eec237414daa61e342')
print(response.json())
# Out:
# {'status': 'error', 'error': 'incorrect_request', 'description': 'Required argument period is missing'}

# %%
import requests

# Установка URL-адреса, куда будет отправлен запрос
url =" &key="

# Создание словаря с данными, которые вы хотите отправить (в данном случае, данные необходимы в теле запроса)
data = {
    "key1": "value1",
    "key2": "value2"
}

# Отправка POST-запроса
response = requests.post(url, json=data)

# Проверка статуса ответа
if response.status_code == 200:
    print("Запрос успешно выполнен")
else:
    print("Произошла ошибка при выполнении запроса")
# Out:
# Запрос успешно выполнен

# %%
import requests

# Установка URL-адреса, откуда будут запрашиваться данные
url = "https://cloud.roistat.com/api/v1/project/analytics/dimensions?project=75873"

# Заголовки запроса
headers = {
    "Content-type": "application/json",
    "Api-key": "0aae516248a720eec237414daa61e342"
}

# Отправка POST-запроса и получение ответа
response = requests.post(url, headers=headers)

# Проверка статуса ответа
if response.status_code == 200:
    data = response.json()
    print("Запрос успешно выполнен")

    # Обработка полученных данных
    if "result" in data:
        result = data["result"]
        # Далее можно производить операции с данными
        # Например, вывести результат на экран
        for item in result:
            print(item)
    else:
        print("Ошибка: 'result' отсутствует в ответе")

else:
    print("Произошла ошибка при выполнении запроса")
# Out:
# Запрос успешно выполнен
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 16>()
#      18 print("Запрос успешно выполнен")
#      20 # Обработка полученных данных
# ---> 21 if result in data:
#      22     result = data[result]
#      23     # Далее можно производить операции с данными
#      24     # Например, вывести результат на экран
#
# NameError: name 'result' is not defined

# %%
import requests
import pandas as pd

# Установка URL-адреса, откуда будут запрашиваться данные
url = "https://cloud.roistat.com/api/v1/project/analytics/dimensions?project=75873"

# Заголовки запроса
headers = {
    "Content-type": "application/json",
    "Api-key": "0aae516248a720eec237414daa61e342"
}

# Отправка POST-запроса и получение ответа
response = requests.post(url, headers=headers)

# Проверка статуса ответа
if response.status_code == 200:
    data = response.json()
    print("Запрос успешно выполнен")

    # Обработка полученных данных
    if "dimensions" in data:
        result = data["dimensions"]
        
        # Создание датафрейма из списка словарей
        df = pd.DataFrame(result)
        
        # Вывод датафрейма на экран
        print(df)
        
    else:
        print("Ошибка: 'dimensions' отсутствует в ответе")

else:
    print("Произошла ошибка при выполнении запроса")
# Out:
# Запрос успешно выполнен
#                    name                         title  order          group  \
# 0        marker_level_1          Источник (уровень 1)    100        sources
# 1        marker_level_2          Источник (уровень 2)    200        sources
# 2        marker_level_3          Источник (уровень 3)    300        sources
# 3        marker_level_4          Источник (уровень 4)    400        sources
# 4        marker_level_5          Источник (уровень 5)    500        sources
# ..                  ...                           ...    ...            ...
# 236  product_category_1  Категория товара (уровень 1)   6000  order_product
# 237  product_category_2  Категория товара (уровень 2)   6100  order_product
# 238  product_category_3  Категория товара (уровень 3)   6200  order_product
# 239  product_category_4  Категория товара (уровень 4)   6300  order_product
# 240  product_category_5  Категория товара (уровень 5)   6400  order_product
#
#      is_filtration_disabled
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ..                      ...
# 236                   False
# 237                   False
# 238                   False
# 239                   False
# 240                   False
#
# [241 rows x 5 columns]

# %%
data
# Out:
# {'dimensions': [{'name': 'marker_level_1',
#    'title': 'Источник (уровень 1)',
#    'order': 100,
#    'group': 'sources',
#    'is_filtration_disabled': False},
#   {'name': 'marker_level_2',
#    'title': 'Источник (уровень 2)',
#    'order': 200,
#    'group': 'sources',
#    'is_filtration_disabled': False},
#   {'name': 'marker_level_3',
#    'title': 'Источник (уровень 3)',
#    'order': 300,
#    'group': 'sources',
#    'is_filtration_disabled': False},
#   {'name': 'marker_level_4',
#    'title': 'Источник (уровень 4)',
#    'order': 400,
#    'group': 'sources',
#    'is_filtration_disabled': False},
#   {'name': 'marker_level_5',
#    'title': 'Источник (уровень 5)',
#    'order': 500,
#    'group': 'sources',
#    'is_filtration_disabled': False},
#   {'name': 'marker_level_6',
#    'title': 'Источник (уровень 6)',
#    'order': 600,
#    'group': 'sources',
#    'is_filtration_disabled': False},
#   {'name': 'marker_level_7',
#    'title': 'Источник (уровень 7)',
#    'order': 700,
#    'group': 'sources',
#    'is_filtration_disabled': False},
#   {'name': 'utm_source',
#    'title': 'utm_source',
#    'order': 800,
#    'group': 'utm',
#    'is_filtration_disabled': False},
#   {'name': 'utm_medium',
#    'title': 'utm_medium',
#    'order': 900,
#    'group': 'utm',
#    'is_filtration_disabled': False},
#   {'name': 'utm_campaign',
#    'title': 'utm_campaign',
#    'order': 1000,
#    'group': 'utm',
#    'is_filtration_disabled': False},
#   {'name': 'utm_term',
#    'title': 'utm_term',
#    'order': 1100,
#    'group': 'utm',
#    'is_filtration_disabled': False},
#   {'name': 'utm_content',
#    'title': 'utm_content',
#    'order': 1200,
#    'group': 'utm',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param1',
#    'title': 'roistat_param1',
#    'order': 1300,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param2',
#    'title': 'roistat_param2',
#    'order': 1400,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param3',
#    'title': 'roistat_param3',
#    'order': 1500,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param4',
#    'title': 'roistat_param4',
#    'order': 1600,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param5',
#    'title': 'roistat_param5',
#    'order': 1700,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'host',
#    'title': 'Домен',
#    'order': 1800,
#    'group': 'landing_page',
#    'is_filtration_disabled': False},
#   {'name': 'landing_page',
#    'title': 'Посадочная страница',
#    'order': 1900,
#    'group': 'landing_page',
#    'is_filtration_disabled': False},
#   {'name': 'protocol',
#    'title': 'Протокол',
#    'order': 1901,
#    'group': 'device_browser',
#    'is_filtration_disabled': False},
#   {'name': 'referrer',
#    'title': 'Источник',
#    'order': 2000,
#    'group': 'source_page',
#    'is_filtration_disabled': False},
#   {'name': 'referrer_host',
#    'title': 'Домен источника',
#    'order': 2100,
#    'group': 'source_page',
#    'is_filtration_disabled': False},
#   {'name': 'country',
#    'title': 'Страна',
#    'order': 2200,
#    'group': 'geo',
#    'is_filtration_disabled': False},
#   {'name': 'region',
#    'title': 'Регион',
#    'order': 2250,
#    'group': 'geo',
#    'is_filtration_disabled': False},
#   {'name': 'city',
#    'title': 'Город',
#    'order': 2300,
#    'group': 'geo',
#    'is_filtration_disabled': False},
#   {'name': 'device',
#    'title': 'Устройство',
#    'order': 1005002,
#    'group': 'device_browser',
#    'is_filtration_disabled': False},
#   {'name': 'browser',
#    'title': 'Браузер',
#    'order': 1005003,
#    'group': 'device_browser',
#    'is_filtration_disabled': False},
#   {'name': 'ad_position_type',
#    'title': 'Блок показа',
#    'order': 2400,
#    'group': 'source_page',
#    'is_filtration_disabled': False},
#   {'name': 'ad_position',
#    'title': 'Позиция показа',
#    'order': 2500,
#    'group': 'source_page',
#    'is_filtration_disabled': False},
#   {'name': 'search_phrase',
#    'title': 'Поисковый запрос',
#    'order': 2600,
#    'group': 'source_page',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param6',
#    'title': 'roistat_param6',
#    'order': 1706,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param7',
#    'title': 'roistat_param7',
#    'order': 1707,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param8',
#    'title': 'roistat_param8',
#    'order': 1708,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param9',
#    'title': 'roistat_param9',
#    'order': 1709,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param10',
#    'title': 'roistat_param10',
#    'order': 1710,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param11',
#    'title': 'roistat_param11',
#    'order': 1711,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param12',
#    'title': 'roistat_param12',
#    'order': 1712,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param13',
#    'title': 'roistat_param13',
#    'order': 1713,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param14',
#    'title': 'roistat_param14',
#    'order': 1714,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param15',
#    'title': 'roistat_param15',
#    'order': 1715,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param16',
#    'title': 'roistat_param16',
#    'order': 1716,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param17',
#    'title': 'roistat_param17',
#    'order': 1717,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param18',
#    'title': 'roistat_param18',
#    'order': 1718,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param19',
#    'title': 'roistat_param19',
#    'order': 1719,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param20',
#    'title': 'roistat_param20',
#    'order': 1720,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param21',
#    'title': 'roistat_param21',
#    'order': 1721,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param22',
#    'title': 'roistat_param22',
#    'order': 1722,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param23',
#    'title': 'roistat_param23',
#    'order': 1723,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param24',
#    'title': 'roistat_param24',
#    'order': 1724,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param25',
#    'title': 'roistat_param25',
#    'order': 1725,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param26',
#    'title': 'roistat_param26',
#    'order': 1726,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param27',
#    'title': 'roistat_param27',
#    'order': 1727,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param28',
#    'title': 'roistat_param28',
#    'order': 1728,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param29',
#    'title': 'roistat_param29',
#    'order': 1729,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param30',
#    'title': 'roistat_param30',
#    'order': 1730,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param31',
#    'title': 'roistat_param31',
#    'order': 1731,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param32',
#    'title': 'roistat_param32',
#    'order': 1732,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param33',
#    'title': 'roistat_param33',
#    'order': 1733,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param34',
#    'title': 'roistat_param34',
#    'order': 1734,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param35',
#    'title': 'roistat_param35',
#    'order': 1735,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param36',
#    'title': 'roistat_param36',
#    'order': 1736,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param37',
#    'title': 'roistat_param37',
#    'order': 1737,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param38',
#    'title': 'roistat_param38',
#    'order': 1738,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param39',
#    'title': 'roistat_param39',
#    'order': 1739,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param40',
#    'title': 'roistat_param40',
#    'order': 1740,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param41',
#    'title': 'roistat_param41',
#    'order': 1741,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param42',
#    'title': 'roistat_param42',
#    'order': 1742,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param43',
#    'title': 'roistat_param43',
#    'order': 1743,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param44',
#    'title': 'roistat_param44',
#    'order': 1744,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param45',
#    'title': 'roistat_param45',
#    'order': 1745,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param46',
#    'title': 'roistat_param46',
#    'order': 1746,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param47',
#    'title': 'roistat_param47',
#    'order': 1747,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param48',
#    'title': 'roistat_param48',
#    'order': 1748,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param49',
#    'title': 'roistat_param49',
#    'order': 1749,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'roistat_param50',
#    'title': 'roistat_param50',
#    'order': 1750,
#    'group': 'roistat_params',
#    'is_filtration_disabled': False},
#   {'name': 'daily',
#    'title': 'День визита',
#    'order': 2700,
#    'group': 'time',
#    'is_filtration_disabled': True},
#   {'name': 'weekly',
#    'title': 'Неделя визита',
#    'order': 2900,
#    'group': 'time',
#    'is_filtration_disabled': True},
#   {'name': 'monthly',
#    'title': 'Месяц визита',
#    'order': 3600,
#    'group': 'time',
#    'is_filtration_disabled': True},
#   {'name': 'order_creation_day',
#    'title': 'День заявки',
#    'order': 3700,
#    'group': 'time',
#    'is_filtration_disabled': True},
#   {'name': 'order_creation_week',
#    'title': 'Неделя заявки',
#    'order': 3800,
#    'group': 'time',
#    'is_filtration_disabled': True},
#   {'name': 'order_creation_month',
#    'title': 'Месяц заявки',
#    'order': 3900,
#    'group': 'time',
#    'is_filtration_disabled': True},
#   {'name': 'order_creation_week_day',
#    'title': 'День недели заявки',
#    'order': 4000,
#    'group': 'time',
#    'is_filtration_disabled': False},
#   {'name': 'order_creation_hour',
#    'title': 'Час заявки',
#    'order': 4100,
#    'group': 'time',
#    'is_filtration_disabled': False},
#   {'name': 'order_paid_daily',
#    'title': 'День продажи',
#    'order': 4200,
#    'group': 'time',
#    'is_filtration_disabled': True},
#   {'name': 'order_paid_weekly',
#    'title': 'Неделя продажи',
#    'order': 4300,
#    'group': 'time',
#    'is_filtration_disabled': True},
#   {'name': 'order_paid_monthly',
#    'title': 'Месяц продажи',
#    'order': 4400,
#    'group': 'time',
#    'is_filtration_disabled': True},
#   {'name': 'order_paid_week_days',
#    'title': 'День недели продажи',
#    'order': 4500,
#    'group': 'time',
#    'is_filtration_disabled': False},
#   {'name': 'order_paid_hours',
#    'title': 'Час продажи',
#    'order': 4600,
#    'group': 'time',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_1',
#    'title': 'Менеджер',
#    'order': 3300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_2',
#    'title': 'Воронка продаж',
#    'order': 3400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_3',
#    'title': 'Бюджет',
#    'order': 3500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_4',
#    'title': 'tags',
#    'order': 3600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_6',
#    'title': 'Статус сделки',
#    'order': 3700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_7',
#    'title': 'Категория номера(тур)',
#    'order': 3800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_8',
#    'title': 'Оценка скрипта',
#    'order': 3900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_9',
#    'title': 'Комментарий КК',
#    'order': 4000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_10',
#    'title': 'Ведение CRM',
#    'order': 4100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_11',
#    'title': 'Проверено',
#    'order': 4200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_13',
#    'title': 'Причина провала сделки',
#    'order': 4300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_14',
#    'title': 'Проверено КК',
#    'order': 4400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_15',
#    'title': 'Компания',
#    'order': 4500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_16',
#    'title': 'Группа пользователей',
#    'order': 4600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_17',
#    'title': 'TRANID',
#    'order': 4700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_18',
#    'title': 'FORMNAME',
#    'order': 4800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_19',
#    'title': 'FORMID',
#    'order': 4900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_20',
#    'title': 'REFERER',
#    'order': 5000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_21',
#    'title': 'КОЛ-ВО_ГОСТЕЙ',
#    'order': 5100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_22',
#    'title': 'Цель поездки',
#    'order': 5200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_23',
#    'title': 'Сколько планируете человек для проживания в отеле?',
#    'order': 5300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_24',
#    'title': 'Дети',
#    'order': 5400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_25',
#    'title': 'Отдаленность от моря',
#    'order': 5500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_26',
#    'title': 'услуги',
#    'order': 5600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_27',
#    'title': 'Галочка',
#    'order': 5700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_28',
#    'title': 'Система питания',
#    'order': 5800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_29',
#    'title': 'Когда планируете приехать?',
#    'order': 5900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_30',
#    'title': 'Куда отправить',
#    'order': 6000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_31',
#    'title': 'Адрес страницы',
#    'order': 6100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_32',
#    'title': 'Форма',
#    'order': 6200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_33',
#    'title': 'ip',
#    'order': 6300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_34',
#    'title': 'Количество звезд',
#    'order': 6400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_35',
#    'title': 'url',
#    'order': 6500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_36',
#    'title': 'ROISTAT_URL',
#    'order': 6600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_37',
#    'title': 'Дата заезда',
#    'order': 6700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_38',
#    'title': 'Дата выезда',
#    'order': 6800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_39',
#    'title': 'INPUT',
#    'order': 6900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_40',
#    'title': 'REVIW',
#    'order': 7000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_41',
#    'title': 'Выбор заголовка',
#    'order': 7100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_42',
#    'title': 'Имя гостя',
#    'order': 7200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_43',
#    'title': 'Выберите отель',
#    'order': 7300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_44',
#    'title': 'Откуда пришел гость?',
#    'order': 7400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_46',
#    'title': 'Повторное обращение?',
#    'order': 7500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_47',
#    'title': 'Нецелевой',
#    'order': 7600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_48',
#    'title': 'COOKIES',
#    'order': 7700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_49',
#    'title': 'КОЛИЧЕСТВО_ГОСТЕЙ',
#    'order': 7800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_50',
#    'title': 'Объект',
#    'order': 7900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_51',
#    'title': 'Услуга',
#    'order': 8000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_52',
#    'title': 'Причина отказа СПА',
#    'order': 8100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_53',
#    'title': 'Дубль?',
#    'order': 8200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_54',
#    'title': 'СРОЧНО КП-Сочи',
#    'order': 8300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_55',
#    'title': 'СРОЧНО Адлер',
#    'order': 8400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_56',
#    'title': 'Сделка с сайта',
#    'order': 8500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_57',
#    'title': 'ой',
#    'order': 8600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_58',
#    'title': 'Причины закрытия сделок',
#    'order': 8700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_59',
#    'title': 'Комментарий клиента',
#    'order': 8800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_60',
#    'title': 'Статус звонка автопрозвон',
#    'order': 8900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_61',
#    'title': 'Автопрозвон текст ответа',
#    'order': 9000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_62',
#    'title': 'Интерес клиента',
#    'order': 9100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_63',
#    'title': 'Причина отказа',
#    'order': 9200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_64',
#    'title': 'Ответ гостя',
#    'order': 9300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_65',
#    'title': 'Без отклика вотсап',
#    'order': 9400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_66',
#    'title': 'Цель вашей поездки ?',
#    'order': 9500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_67',
#    'title': 'Желаете приехать с детьми?',
#    'order': 9600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_68',
#    'title': 'Какое месторасположение отеля рассматриваете?',
#    'order': 9700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_69',
#    'title': 'Наличие каких преимуществ отеля для Вас важно?',
#    'order': 9800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_70',
#    'title': 'Отели с каким количеством звёзд рассматриваете?',
#    'order': 9900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_71',
#    'title': 'Какую систему питания рассматриваете?',
#    'order': 10000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_72',
#    'title': 'Цель вашей поездки? (2)',
#    'order': 10100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_73',
#    'title': 'Как удобней с Вами связаться?',
#    'order': 10200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_74',
#    'title': 'referrer',
#    'order': 10300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_75',
#    'title': 'Выберите себе подарок',
#    'order': 10400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_76',
#    'title': 'Сколько звёзд рассматриваете?',
#    'order': 10500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_77',
#    'title': 'Какой отдых вы предпочитаете?',
#    'order': 10600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_78',
#    'title': 'Анкета',
#    'order': 10700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_79',
#    'title': 'Укажите желаемые даты поездки',
#    'order': 10800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_80',
#    'title': 'Источник',
#    'order': 10900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_81',
#    'title': 'Степень срочности',
#    'order': 11000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_82',
#    'title': 'ты проверил причичину ?',
#    'order': 11100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_83',
#    'title': 'Указал причину закрытия?',
#    'order': 11200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_84',
#    'title': 'Указал причину?',
#    'order': 11300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_85',
#    'title': 'Примечание 1С',
#    'order': 11400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_87',
#    'title': 'В работе у коллектора',
#    'order': 11500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_88',
#    'title': 'Работал квизербот',
#    'order': 11600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_89',
#    'title': '_ym_uid',
#    'order': 11700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_90',
#    'title': 'Какой квизербот работал?',
#    'order': 11800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_91',
#    'title': 'Где бы хотели отдохнуть?',
#    'order': 11900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_93',
#    'title': 'Цель вашей поездки?',
#    'order': 12000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_94',
#    'title': 'Сколько планируете человек для проживания',
#    'order': 12100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_95',
#    'title': 'Как месторасположение рассматриваете?',
#    'order': 12200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_96',
#    'title': 'Наличие каких преимуществ отеля для Вас важно',
#    'order': 12300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_97',
#    'title': 'Выберите свой подарок:',
#    'order': 12400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_98',
#    'title': 'Страница',
#    'order': 12500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_99',
#    'title': 'Сумма счёта',
#    'order': 12600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_100',
#    'title': 'КБ в 1С',
#    'order': 12700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_101',
#    'title': 'Входящий номер',
#    'order': 12800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_102',
#    'title': 'Calltraking',
#    'order': 12900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_103',
#    'title': 'Тип обращения',
#    'order': 13000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_104',
#    'title': 'Номер счёта интернет эквайринг',
#    'order': 13100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_105',
#    'title': 'Статус платежа интернет эквайринг',
#    'order': 13200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_106',
#    'title': 'fbclid',
#    'order': 13300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_107',
#    'title': 'Было в работе у аккаунта',
#    'order': 13400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_108',
#    'title': 'Статус бронирования travellline',
#    'order': 13500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_109',
#    'title': 'Бот отрабатывал сценарий',
#    'order': 13600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_110',
#    'title': 'Работал бот ТУ',
#    'order': 13700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_111',
#    'title': 'Какая ветка сценария бота?',
#    'order': 13800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_112',
#    'title': 'gclientid',
#    'order': 13900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_113',
#    'title': 'ФИО',
#    'order': 14000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_114',
#    'title': 'yclid',
#    'order': 14100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_115',
#    'title': '_ym_counter',
#    'order': 14200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_116',
#    'title': 'Онлайн чат ВЗП',
#    'order': 14300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_117',
#    'title': 'Телефон',
#    'order': 14400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_118',
#    'title': 'Сколько планируете человек для проживания в отеле? (NEW)',
#    'order': 14500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_119',
#    'title': 'Выбор подарка',
#    'order': 14600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_120',
#    'title': 'Ссылка на счёт',
#    'order': 14700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_121',
#    'title': 'Заявка',
#    'order': 14800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_122',
#    'title': 'Причина закрытия',
#    'order': 14900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_123',
#    'title': 'Сценарий онлайн чата',
#    'order': 15000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_124',
#    'title': 'Домен сайта',
#    'order': 15100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_125',
#    'title': 'Комментарий к сделке',
#    'order': 15200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_126',
#    'title': 'Новый лид',
#    'order': 15300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_127',
#    'title': 'Что выбрал клиент вотсап (1)',
#    'order': 15400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_128',
#    'title': 'Закрытие текущие обращения',
#    'order': 15500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_129',
#    'title': 'Группа?',
#    'order': 15600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_130',
#    'title': 'Как удобно вести коммуникацию?',
#    'order': 15700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_131',
#    'title': 'Q_Домен сайта',
#    'order': 15800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_132',
#    'title': 'Q_Цель вашей поездки?',
#    'order': 15900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_133',
#    'title': 'Q_Сколько планируете человек для проживания в отеле?',
#    'order': 16000,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_134',
#    'title': 'Q_Желаете приехать с детьми?',
#    'order': 16100,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_135',
#    'title': 'Q_Какое месторасположение отеля рассматриваете?',
#    'order': 16200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_136',
#    'title': 'Q_ Интересует конкретное местоположение?',
#    'order': 16300,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_137',
#    'title': 'Q_Когда хотите забронировать?',
#    'order': 16400,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_138',
#    'title': 'Q_Как вам удобнее общаться?',
#    'order': 16500,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_139',
#    'title': 'Q_Выберите свой подарок:',
#    'order': 16600,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_field_140',
#    'title': 'Q_Приоритет',
#    'order': 16700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'event_meta_id',
#    'title': 'События',
#    'order': 3100,
#    'group': 'events',
#    'is_filtration_disabled': False},
#   {'name': 'order_page',
#    'title': 'Страница заявки',
#    'order': 3200,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_round_daily',
#    'title': 'Цикл сделки (дни)',
#    'order': 4700,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_round_weekly',
#    'title': 'Цикл сделки (недели)',
#    'order': 4800,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'order_round_monthly',
#    'title': 'Цикл сделки (месяцы)',
#    'order': 4900,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'hours',
#    'title': 'Час визита',
#    'order': 2650,
#    'group': 'time',
#    'is_filtration_disabled': False},
#   {'name': 'week_days',
#    'title': 'День недели визита',
#    'order': 2800,
#    'group': 'time',
#    'is_filtration_disabled': False},
#   {'name': 'device_type',
#    'title': 'Тип устройства',
#    'order': 1005001,
#    'group': 'device_browser',
#    'is_filtration_disabled': False},
#   {'name': 'order_engine_type',
#    'title': 'Способ создания заявки',
#    'order': 3250,
#    'group': 'leads',
#    'is_filtration_disabled': False},
#   {'name': 'source_group',
#    'title': 'Группа каналов',
#    'order': 1005005,
#    'group': 'sources',
#    'is_filtration_disabled': False},
#   {'name': 'product_name',
#    'title': 'Наименование товара',
#    'order': 5700,
#    'group': 'order_product',
#    'is_filtration_disabled': False},
#   {'name': 'product_brand',
#    'title': 'Бренд товара',
#    'order': 5800,
#    'group': 'order_product',
#    'is_filtration_disabled': False},
#   {'name': 'product_variant',
#    'title': 'Вариант товара',
#    'order': 5900,
#    'group': 'order_product',
#    'is_filtration_disabled': False},
#   {'name': 'product_category_1',
#    'title': 'Категория товара (уровень 1)',
#    'order': 6000,
#    'group': 'order_product',
#    'is_filtration_disabled': False},
#   {'name': 'product_category_2',
#    'title': 'Категория товара (уровень 2)',
#    'order': 6100,
#    'group': 'order_product',
#    'is_filtration_disabled': False},
#   {'name': 'product_category_3',
#    'title': 'Категория товара (уровень 3)',
#    'order': 6200,
#    'group': 'order_product',
#    'is_filtration_disabled': False},
#   {'name': 'product_category_4',
#    'title': 'Категория товара (уровень 4)',
#    'order': 6300,
#    'group': 'order_product',
#    'is_filtration_disabled': False},
#   {'name': 'product_category_5',
#    'title': 'Категория товара (уровень 5)',
#    'order': 6400,
#    'group': 'order_product',
#    'is_filtration_disabled': False}],
#  'status': 'success'}

# %%
response = requests.get(url='http://httpbin.org/')
print(response.text)

# %%
# Для того,  чтобы скачать медиа-файл, используйте менеджер контекста with
# Возвращает строку байтов 'wb' запись байтов

response = requests.get(url='http://httpbin.org/image/jpeg')
with open('image.jpeg', 'wb') as file:
    file.write(response.content)

# %%
for i in range(1, 161):
    response = requests.get(url=f'http://parsinger.ru/img_download/img/ready/{i}.png')
    with open(f'image/{i}.jpeg', 'wb') as file:
        file.write(response.content)

# %% [markdown]
# ## BeautifulSoup4

# %%
# Пример 1. Передача файла HTML напрямую без использования менеджера контекста
file = open('index/index.html', encoding='utf-8')
soup = BeautifulSoup(file, 'lxml')
file.close()
print(soup)

# %%
# Пример 2. Передача файла HTML напрямую с использованем менеджера контекста
with open('index.html', 'r', encoding='utf-8') as file:
    soup2 = BeautifulSoup(file, 'lxml')
    print(soup2)

# %%
# Пример 3. Передача объекта response прямо из запроса
response = requests.get(url='http://parsinger.ru/html/watch/1/1_1.html')
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')

print(soup)

# %%
url = 'https://parsinger.ru/html/index1_page_1.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
div = soup.find('div', 'item')
print(type(div))
print(div)

# %%
url = 'http://parsinger.ru/html/index1_page_1.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
div = soup.find('div', 'item').find_all('li')
for txt in div:
    print(txt.text)

# %%
url = 'http://parsinger.ru/html/index1_page_1.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
#div = soup.find('div', 'item').find_all('li')

div = [x.text for x in soup.find('div', 'item').find_all('li')]
# тоже самое
# result = []
# for txt in div:
#     result.append(txt)
print(div)

# %%
# Поиск по class
url = 'http://parsinger.ru/html/headphones/5/5_32.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
div = soup.find('p', class_='article').text
print(div)

# %%
# Поиск по id
url = 'http://parsinger.ru/html/headphones/5/5_32.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
div = soup.find('p', id='p_header').text
print(div)

# %%
# Поиск по атрибутам
url = 'http://parsinger.ru/html/headphones/5/5_32.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
div = soup.find('span', {'name': 'count'}).text
print(div)

# %%
# стоимости часов (всего 8 шт)
url = 'http://parsinger.ru/html/index1_page_1.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
# div = soup.find('div', 'item').find_all('li')
#div=soup.find_all("p",class_="price")
div = [x.text for x in soup.find_all('p', class_='price')]
print(div)
sum_=0
for i in div:
    string = i.replace("руб", "")
    x = int(string)
    sum_+=int(x)
print(sum_)
# Out:
# ['2310 руб', '5480 руб', '21810 руб', '21810 руб', '27770 руб', '27770 руб', '24230 руб', '32600 руб']
# 163780

# %%
# высчитываем процент скидки
url = 'https://parsinger.ru/html/hdd/4/4_1.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
# div = soup.find('div', 'item').find_all('li')
#div=soup.find_all("p",class_="price")
price_ = soup.find('span', id='price').text
price = price_.replace("руб", "")
old_price_ = soup.find('span', id='old_price').text
old_price = old_price_.replace("руб", "")
x=int(price)
y=int(old_price)
discount=(y-x)*100/y
print(round(discount,1))

# %% [markdown]
# ## Пагинация
# Пагинация (от слова page - “страница”)

# %%
#  соберем ссылки из пагинации, также нам понадобится значение последнего элемента
url = 'http://parsinger.ru/html/index1_page_3.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
pagen = soup.find('div', class_='pagen').find_all('a')

print(pagen)

# %%
#  генерировать корректные ссылки, полные
url = 'http://parsinger.ru/html/index1_page_3.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
pagen = soup.find('div', class_='pagen').find_all('a')

list_link = []
shema = 'http://parsinger.ru/html/'
for link in pagen:
    list_link.append(f"{shema}{link['href']}")

print(list_link)

# %%
# с применением list comprehension:
url = 'http://parsinger.ru/html/index1_page_3.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
shema = 'http://parsinger.ru/html/'
pagen = [f"{shema}{link['href']}" for link in soup.find('div', class_='pagen').find_all('a')]

print(pagen)

# %%
# генерация ссылок
link = []
for i in range(1, 101):
    link.append(f'https://www.wildberries.ru/catalog/elektronika/smart-chasy?sort=popular&page={i}')
print(link)

# %%
# извлечь последнее значение из пагинации 

url = 'http://parsinger.ru/html/index1_page_3.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
shema = 'http://parsinger.ru/html/'
pagen = [link for link in soup.find('div', class_='pagen').find_all('a')][-1]

print(pagen)

# %%
url = 'http://parsinger.ru/html/index3_page_1.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
#div = soup.find('div', 'item').find_all('li')

div = [x.text for x in soup.find('div', 'item').find_all('li')]
# тоже самое
# result = []
# for txt in div:
#     result.append(txt)
print(div)

# %%
# Извлеките названия товара с каждой страницы,
url = 'http://parsinger.ru/html/index3_page_1.html'
response = requests.get(url=url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
div = [x.text for x in soup.find_all('a', class_='name_item')]
print(div)
# Данные с каждой страницы должны хранится в списке
# pagen = soup.find('div', class_='pagen').find_all('a')
shema = 'http://parsinger.ru/html/'
pagen = [f"{shema}{link['href']}" for link in soup.find('div', class_='pagen').find_all('a')]

print(pagen)

# %%
for i in range(1, 5):
    response = requests.get(url=f'http://parsinger.ru/html/index3_page_{i}.html')
    response.encoding = 'utf-8'
    print(response.text)

# %%
# тоже самое в List comprehensions
[requests.get(url=f'http://parsinger.ru/html/index3_page_{i}.html') for i in range(1,5)]

# %%
# List comprehensions создаёт список списков
data = [
    [i * j for i in range(0, 2)] # заполняет вложенные списки данными
        for j in range(0, 4)     # создайте список с вложенными списками
]
print(data)

# %%
for i in range(1, 5):
    response = requests.get(url=f'http://parsinger.ru/html/index3_page_{i}.html')
    response.encoding = 'utf-8'
    # res = []
    # for soup in BeautifulSoup(response.text, 'lxml'):
    #     res = [x.text for x in soup.find_all('a', class_='name_item')]
    print(response. )

# %%
# пример создания списков в списке
board = []    
for i in range(4): # создайте список с вложенными списками
    board.append([])
    for n in range(2):
        board[i].append("O") # заполняет вложенные списки данными
print(board)

# %%
# Извлеките названия товара с каждой страницы
res = []
for i in range(1,4):
    response = requests.get(url=f'http://parsinger.ru/html/index3_page_{i}.html')
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'lxml')
    name = [x.text for x in soup.find_all('a', class_='name_item')]
    #res.append(name)
    #print(name)
    res.append(name)
print(res)
# Out:
# [[' Vampire RGB,9 кнопок ', 'Defender Halo Z GM-430L', ' Defender Shark 2 ', ' Defender sTarx GM-390L ', ' Defender Skull GM-180L ', ' Defender Killer GM-170L ', ' Defender Ghost GM-190L ', ' Defender Witcher GM-990 '], [' Logitech G305 LIGHTSPEED Wireless ', ' Logitech G102 LIGHTSYNC Gaming', ' Logitech G PRO HERO Black ', ' Logitech G402 Hyperion Fury ', ' STM 109CW ', ' Defender MB-986 ', ' Gembird MG-520 ', ' CBR CM 846 '], [' Гарнизон GM-720G ', ' Гарнизон GM-700G ', ' Гарнизон GM-760G ', ' Гарнизон GM-730G ', ' Гарнизон GM-620G ', ' A4TECH Bloody Q51 ', ' MGK-03U Dialog Gan-Kata ', ' Defender Flash MB-600L ']]

# %%
# пример функци
class VazonParser:
    def __init__(self):
        self.descriptions = []

    def __get_response(self, url):
        response = requests.get(url=url)
        response.encoding = 'utf-8'
        return response

    def __find_pages(self, response, site):
        soup = BeautifulSoup(response.text, 'lxml')
        pagen = map(lambda x: site + x['href'], soup.find('div', class_='pagen').find_all('a'))
        return pagen

    def parse_site(self, url, site):
        response = self.__get_response(url)
        for page in self.__find_pages(response, site):
            soup = BeautifulSoup(self.__get_response(page).text, 'lxml')
            raw_text = soup.find_all('a', class_='name_item')
            description = list(map(lambda x: x.text, raw_text))
            self.descriptions.append(description)
        print(self.descriptions)


if __name__ == '__main__':
    url = 'https://parsinger.ru/html/index3_page_1.html'
    site = 'http://parsinger.ru/html/'
    parser = VazonParser()
    parser.parse_site(url, site)
# Out:
# [[' Vampire RGB,9 кнопок ', 'Defender Halo Z GM-430L', ' Defender Shark 2 ', ' Defender sTarx GM-390L ', ' Defender Skull GM-180L ', ' Defender Killer GM-170L ', ' Defender Ghost GM-190L ', ' Defender Witcher GM-990 '], [' Logitech G305 LIGHTSPEED Wireless ', ' Logitech G102 LIGHTSYNC Gaming', ' Logitech G PRO HERO Black ', ' Logitech G402 Hyperion Fury ', ' STM 109CW ', ' Defender MB-986 ', ' Gembird MG-520 ', ' CBR CM 846 '], [' Гарнизон GM-720G ', ' Гарнизон GM-700G ', ' Гарнизон GM-760G ', ' Гарнизон GM-730G ', ' Гарнизон GM-620G ', ' A4TECH Bloody Q51 ', ' MGK-03U Dialog Gan-Kata ', ' Defender Flash MB-600L '], [' Gembird MG-550 ', ' Lenovo Legion M200 ', ' Sven RX-G750 ', ' Wired Gaming Mouse ', ' MSI Clutch GM08 ', '  Gembird MG-760 ', ' MGK-11U Dialog Gan-Kata ', ' Logitech G102 ']]

# %%
# Складываем(плюсуем) все собранные значения
z = 0
for i in range(1,33):
    response = requests.get(url=f'https://parsinger.ru/html/mouse/3/3_{i}.html')
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'lxml')
    name = [x.text[-8:] for x in soup.find('p', class_='article')]
    y = ''.join(name) # converting list into string
    z += int(y)    
print(z)
# Out:
# 2505109532

# %%
# по всем категориям, страницам и карточкам с товарами собираем стоимость товара в наличии
# первым делом добываем все нужные ссылки
index_labels = {1: "watch", 2: "mobile", 3: "mouse", 4: "hdd", 5: "headphones"}
suma=[]
for i in range(5):
    for j in range(32):
        url = f"https://parsinger.ru/html/{index_labels[i+1]}/{i+1}/{i+1}_{j+1}.html"
        
        response = requests.get(url=url)
        response.encoding = 'utf-8'
        soup = BeautifulSoup(response.text, 'lxml')
        stock_ = soup.find('span', id='in_stock').text
        price_ = soup.find('span', id='price').text

        stock = stock_.replace("В наличии: ", "") # не самый лучший способо, если в тексте будет ошибка 
        price = price_.replace(" руб", "")        # или текст измениться, тогда эта конструкция не сработает. Лучше чсерез тиндекс
        x=int(price)
        y=int(stock)
        discount=(y*x)
        suma.append(discount)
sum(suma)
# Out:
# 45067195

# %% [markdown]
# ## AJAX
# (Asynchronous Javascript and XML) - позволяет обновлять данные на сайте без перезагрузки страницы.

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}

url = "https://bitality.cc/Home/GetSum?GiveName=Ethereum&GetName=Bitcoin&Sum=4.1895414&Direction=0"
response = requests.get(url=url, headers=headers).json()
print(response)
# Out:
# {'giveSum': '4.1895414', 'getSum': '0.28697157'}

# %%
# официальный курс валют с сайта Центробанка
headers = {'user-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:106.0) Gecko/20100101 Firefox/106.0',
           'X-Requested-With': 'XMLHttpRequest', }

url = 'https://cbr.ru/Queries/AjaxDataSource/112805'

data_dollar = {
    'DT': '',
    'val_id': 'R01235',
    '_': '1667219511852'
}
data_euro = {
    'DT': '',
    'val_id': 'R01239',
    '_': '1667219511853'
}
response_dollar = requests.get(url=url, headers=headers, params=data_dollar).json()[-1]
response_euro = requests.get(url=url, headers=headers, params=data_euro).json()[-1]

print(f'Дата: {response_dollar["data"][:10]}')
print(f'Курс USD: {response_dollar["curs"]} рублей')
print(f'Курс EUR: {response_euro["curs"]} рублей')
# Out:
# Дата: 2022-11-10
# Курс USD: 61.0611 рублей
# Курс EUR: 61.2445 рублей

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}

data = {
    "GiveName": "Monero",
    "GetName": "Dash",
    "Sum": 100,
    "Direction": 0
}

url = "https://bitality.cc/Home/GetSum?"
response = requests.get(url=url, headers=headers, params=data).json()
print(response)
# Out:
# {'giveSum': '100', 'getSum': '371.3763438'}

# %% [markdown]
# ## 4.7 Парсинг табличных данных

# %%
# Собрать все уникальные числа из таблицы(кроме цифр в заголовке) и суммировать их
response = requests.get(url='https://parsinger.ru/table/1/index.html')
response.encoding = 'utf-8'

soup = BeautifulSoup(response.text, 'lxml')
namber = [x.text for x in soup.find_all('td')]

res =set(namber)
sum_=[float(value) for value in res] 
print(sum(sum_))

# другой пример
# table = soup.find_all('td')
# print(sum(set([float(num.text) for num in table])))
# Out:
# 1240.096

# %%
# Собрать числа с 1го столбца и суммировать их
response = requests.get(url='https://parsinger.ru/table/2/index.html')
soup = BeautifulSoup(response.text, 'lxml')

namber = [x.text for x in soup.select('b:first-child')]
print(sum([float(value) for value in namber]))

# другре решение 
# num = [float(num.text.split()[0]) for num in soup.find_all('tr')]
# print(sum(num[1:]))
# Out:
# 80.726

# %%
# Собрать числа которые выделены жирным шрифтом и суммировать их
response = requests.get(url='https://parsinger.ru/table/3/index.html')
soup = BeautifulSoup(response.text, 'lxml')

namber = [x.text for x in soup.select('b')]
print(sum([float(value) for value in namber]))

# другой вариант
#td = [float(x.text) for x in soup.find_all('td') if x.find('td') != x.find('b')]
#print(sum(td))
# Out:
# 373.32899999999995

# %%
#  Собрать числа в зелёных ячейках и суммировать их
response = requests.get(url='https://parsinger.ru/table/4/index.html')
soup = BeautifulSoup(response.text, 'lxml')

namber = [x.text for x in soup.select('.green')]
print(sum([float(value) for value in namber]))

#td = [float(x.text) for x in soup.find_all('td', class_='green')]
#print(sum(td))
# Out:
# 425.7659999999999

# %%
#  Умножить число в оранжевой ячейке на число в голубой ячейке в той же строке и всё суммировать

response = requests.get(url='https://parsinger.ru/table/5/index.html')
soup = BeautifulSoup(response.text, 'lxml')

l1=[float(x.text) for x in soup.select('.orange')]
l2=[float(x.text) for x in soup.select('td:last-child')]

sum_ = [a * b for a, b in zip(l1, l2)]
sum(sum_)
# Out:
# 2521465.6860000016

# %%
# Написать скрипт который формирует словарь, 
# где ключ будет автоматически формироваться из заголовка столбцов, 
# а значения это сумма всех чисел в столбце
response = requests.get(url='https://parsinger.ru/table/5/index.html')
soup = BeautifulSoup(response.text, 'lxml')
td = [float(x.find('td').text) for x in soup.find_all('tr') if x.find('td')]
print(sum(td))
# Out:
# 505.2060000000001
